# %% [markdown]
# <H1>Train Data Exploratory Data Analysis (EDA)</H1>

# %% [markdown]
# <H3>1. Install Packages</H3>

# %%
# Import Packages

import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <H3>2. Get Train Data and Read it with Pandas</H3>

# %%
# Load Data into DataFrame

df = pd.read_csv("../data/train_data.csv")

# %% [markdown]
# <H3>3. Explore the Data in the DataFrame</H3>

# %%
# Get Basic df Shape

df.shape
# Out:
# (26048, 15)

# %%
# Inspect First Five Rows

df.head()
# Out:
#    age  workclass   fnlgt     education  education-num      marital-status  \
# 0   54    Private   88278     Doctorate             16  Married-civ-spouse
# 1   25    Private  297531     Bachelors             13       Never-married
# 2   47  State-gov  223944  Some-college             10  Married-civ-spouse
# 3   20    Private  140764  Some-college             10       Never-married
# 4   59    Private  193895       HS-grad              9            Divorced
#
#         occupation   relationship   race     sex  capital-gain  capital-loss  \
# 0   Prof-specialty        Husband  White    Male             0          1977
# 1            Sales      Own-child  White  Female             0             0
# 2     Adm-clerical           Wife  White  Female             0             0
# 3    Other-service      Own-child  White  Female             0             0
# 4  Exec-managerial  Not-in-family  White  Female             0             0
#
#    hours-per-week native-country salary
# 0              50  United-States   >50K
# 1              40  United-States  <=50K
# 2              30  United-States  <=50K
# 3              20  United-States  <=50K
# 4              40  United-States  <=50K

# %%
# Inspect Last Five Rows

df.tail()
# Out:
#        age         workclass   fnlgt     education  education-num  \
# 26043   46           Private  695411       HS-grad              9
# 26044   34           Private  191291  Some-college             10
# 26045   42       Federal-gov   74680       Masters             14
# 26046   21  Self-emp-not-inc   74538  Some-college             10
# 26047   52  Self-emp-not-inc  175029          10th              6
#
#            marital-status    occupation   relationship   race     sex  \
# 26043            Divorced  Adm-clerical  Not-in-family  White  Female
# 26044       Never-married  Craft-repair  Not-in-family  White    Male
# 26045            Divorced  Adm-clerical  Not-in-family  White    Male
# 26046       Never-married  Tech-support  Not-in-family  White    Male
# 26047  Married-civ-spouse  Craft-repair        Husband  White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 26043             0             0              44  United-States  <=50K
# 26044             0             0              40  United-States  <=50K
# 26045             0          2001              60  United-States  <=50K
# 26046             0             0              25  United-States  <=50K
# 26047             0             0              35  United-States  <=50K

# %%
# Inspect Column Info Data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26048 entries, 0 to 26047
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             26048 non-null  int64
#  1   workclass       26048 non-null  object
#  2   fnlgt           26048 non-null  int64
#  3   education       26048 non-null  object
#  4   education-num   26048 non-null  int64
#  5   marital-status  26048 non-null  object
#  6   occupation      26048 non-null  object
#  7   relationship    26048 non-null  object
#  8   race            26048 non-null  object
#  9   sex             26048 non-null  object
#  10  capital-gain    26048 non-null  int64
#  11  capital-loss    26048 non-null  int64
#  12  hours-per-week  26048 non-null  int64
#  13  native-country  26048 non-null  object
#  14  salary          26048 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.0+ MB

# %%
# Summarize Missing Data

df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlgt             0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
# Inspect Column Statistical Data

df.describe()
# Out:
#                 age         fnlgt  education-num  capital-gain  capital-loss  \
# count  26048.000000  2.604800e+04   26048.000000  26048.000000  26048.000000
# mean      38.580467  1.897615e+05      10.070140   1070.024071     87.398265
# std       13.662807  1.054626e+05       2.578628   7374.290648    403.249001
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178638e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.785060e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.373180e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    26048.000000
# mean        40.369856
# std         12.336232
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# <H3>4. Graph the Numeric Data in the DataFrame</H3>

# %%
# Create Histogram of Numeric Column Data

# Set Veriables

Data_Columns = [
    'age',
    'fnlgt',
    'education-num',
    'capital-gain',
    'capital-loss',
    'hours-per-week'
]

Columns = 3
Rows = math.ceil(len(Data_Columns)/Columns)

# Create Figure
fig, axes = plt.subplots(Rows, Columns, figsize=(20, 12))
axes = [axes[i][j] for i in range(Rows) for j in range(Columns)]
sns.set_theme(style="dark", palette="dark", color_codes='b')

# Plot Data
for i, col in zip(range(Rows * Columns), Data_Columns):

    # Create Plot
    ax = sns.histplot(data=df, x=col, ax=axes[i])

    # Set Title
    title = col.replace('_', ' ').title()
    ax.set_title(title, fontsize=16)

# %%
# Create Kernel Density Estimate Plot of Numeric Column Data

# Set Veriables

Data_Columns = [
    'age',
    'fnlgt',
    'education-num',
    'capital-gain',
    'capital-loss',
    'hours-per-week'
]

Columns = 3
Rows = math.ceil(len(Data_Columns)/Columns)

# Create Figure
fig, axes = plt.subplots(Rows, Columns, figsize=(20, 12))
axes = [axes[i][j] for i in range(Rows) for j in range(Columns)]
sns.set_theme(style="darkgrid", palette="dark", color_codes='b')

# Plot Data
for i, col in zip(range(Rows * Columns), Data_Columns):

    # Create Plot
    ax = sns.kdeplot(data=df, x=col, ax=axes[i])

    # Set Title
    title = col.replace('_', ' ').title()
    ax.set_title(title, fontsize=16)

# %%
# Create Boxplot of Numeric Column Data

# Set Veriables

Data_Columns = [
    'age',
    'fnlgt',
    'education-num',
    'capital-gain',
    'capital-loss',
    'hours-per-week'
]

Columns = 3
Rows = math.ceil(len(Data_Columns)/Columns)

# Create Figure
fig, axes = plt.subplots(Rows, Columns, figsize=(20, 12))
axes = [axes[i][j] for i in range(Rows) for j in range(Columns)]
sns.set_theme(style="dark", palette="dark", color_codes='b')

# Plot Data
for i, col in zip(range(Rows * Columns), Data_Columns):

    # Create Plot
    ax = sns.boxplot(data=df, x=col, ax=axes[i])

    # Set Title
    title = col.replace('_', ' ').title()
    ax.set_title(title, fontsize=16)

# %% [markdown]
# <H3>4. Graph the Categorical Data in the DataFrame</H3>

# %%
# Check Workclass Values

df['workclass'].value_counts()
# Out:
# workclass
# Private             18099
# Self-emp-not-inc     2043
# Local-gov            1697
# ?                    1477
# State-gov            1040
# Self-emp-inc          920
# Federal-gov           754
# Without-pay            11
# Never-worked            7
# Name: count, dtype: int64

# %%
# Plot Workclass Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'workclass', color='Blue')
plt.xticks(rotation = 60)


plt.title('Work Class Values', fontsize=14, fontweight='bold')
plt.xlabel('Work Classes', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Education Values

df['education'].value_counts()
# Out:
# education
# HS-grad         8394
# Some-college    5827
# Bachelors       4343
# Masters         1349
# Assoc-voc       1084
# 11th             942
# Assoc-acdm       846
# 10th             759
# 7th-8th          529
# Prof-school      438
# 9th              405
# 12th             349
# Doctorate        331
# 5th-6th          266
# 1st-4th          139
# Preschool         47
# Name: count, dtype: int64

# %%
# Plot Education Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'education', color='Blue')
plt.xticks(rotation = 60)


plt.title('Education Categorical Values', fontsize=14, fontweight='bold')
plt.xlabel('Education Category', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Marital Status Values

df['marital-status'].value_counts()
# Out:
# marital-status
# Married-civ-spouse       11916
# Never-married             8601
# Divorced                  3558
# Separated                  834
# Widowed                    800
# Married-spouse-absent      321
# Married-AF-spouse           18
# Name: count, dtype: int64

# %%
# Plot Marital Status Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'marital-status', color='Blue')
plt.xticks(rotation = 60)


plt.title('Marital Status Values', fontsize=14, fontweight='bold')
plt.xlabel('Marital Status', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Occupation Values

df['occupation'].value_counts()
# Out:
# occupation
# Craft-repair         3285
# Prof-specialty       3261
# Exec-managerial      3261
# Adm-clerical         2986
# Sales                2953
# Other-service        2673
# Machine-op-inspct    1605
# ?                    1484
# Transport-moving     1270
# Handlers-cleaners    1102
# Farming-fishing       777
# Tech-support          733
# Protective-serv       528
# Priv-house-serv       124
# Armed-Forces            6
# Name: count, dtype: int64

# %%
# Plot Occupation Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'occupation', color='Blue')
plt.xticks(rotation = 60)


plt.title('Occupation Categorical Values', fontsize=14, fontweight='bold')
plt.xlabel('Occupation Category', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Relationship Values

df['relationship'].value_counts()
# Out:
# relationship
# Husband           10499
# Not-in-family      6727
# Own-child          4058
# Unmarried          2733
# Wife               1240
# Other-relative      791
# Name: count, dtype: int64

# %%
# Plot Relationship Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'relationship', color='Blue')
plt.xticks(rotation = 60)


plt.title('Relationship Categorical Values', fontsize=14, fontweight='bold')
plt.xlabel('Relationship Category', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Race Values

df['race'].value_counts()
# Out:
# race
# White                 22253
# Black                  2473
# Asian-Pac-Islander      851
# Amer-Indian-Eskimo      255
# Other                   216
# Name: count, dtype: int64

# %%
# Plot Race Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'race', color='Blue')
plt.xticks(rotation = 60)


plt.title('Racial Categorical Values', fontsize=14, fontweight='bold')
plt.xlabel('Racial Category', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Sex Values

df['sex'].value_counts()
# Out:
# sex
# Male      17403
# Female     8645
# Name: count, dtype: int64

# %%
# Plot Sex Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'sex', color='Blue')
plt.xticks(rotation = 60)


plt.title('Sex Categorical Values', fontsize=14, fontweight='bold')
plt.xlabel('Sex', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Native Country Values

df['native-country'].value_counts()
# Out:
# native-country
# United-States                 23329
# Mexico                          513
# ?                               476
# Philippines                     155
# Germany                         110
# Puerto-Rico                      99
# Canada                           98
# El-Salvador                      94
# India                            87
# Cuba                             81
# South                            66
# Jamaica                          65
# England                          64
# China                            59
# Italy                            57
# Dominican-Republic               53
# Vietnam                          53
# Japan                            51
# Guatemala                        51
# Poland                           47
# Columbia                         45
# Taiwan                           38
# Iran                             36
# Haiti                            35
# Portugal                         28
# Greece                           27
# Nicaragua                        26
# France                           24
# Peru                             23
# Ecuador                          22
# Ireland                          15
# Hong                             15
# Trinadad&Tobago                  14
# Cambodia                         14
# Laos                             13
# Thailand                         13
# Hungary                          12
# Yugoslavia                       11
# Honduras                         10
# Scotland                         10
# Outlying-US(Guam-USVI-etc)        8
# Holand-Netherlands                1
# Name: count, dtype: int64

# %%
# Plot Native Country Values

plt.figure(figsize = [24, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'native-country', color='Blue')
plt.xticks(rotation = 60)


plt.title('Native Country Values', fontsize=14, fontweight='bold')
plt.xlabel('Native Country', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Salary Values

df['salary'].value_counts()
# Out:
# salary
# <=50K    19843
# >50K      6205
# Name: count, dtype: int64

# %%
# Plot Salary Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'salary', color='Blue')
plt.xticks(rotation = 60)


plt.title('Salary Group Values', fontsize=14, fontweight='bold')
plt.xlabel('Salary Group', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');
