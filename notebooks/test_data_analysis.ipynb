# %% [markdown]
# <H1>Test Data Exploratory Data Analysis (EDA)</H1>

# %% [markdown]
# <H3>1. Install Packages</H3>

# %%
# Import Packages

import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <H3>2. Get Test Data and Read it with Pandas</H3>

# %%
# Load Data into DataFrame

df = pd.read_csv("../data/test_data.csv")

# %% [markdown]
# <H3>3. Explore the Data in the DataFrame</H3>

# %%
# Get Basic df Shape

df.shape
# Out:
# (6513, 15)

# %%
# Inspect First Five Rows

df.head()
# Out:
#    age         workclass   fnlgt     education  education-num  \
# 0   27           Private  160178  Some-college             10
# 1   45         State-gov   50567       HS-grad              9
# 2   29           Private  185908     Bachelors             13
# 3   30           Private  190040     Bachelors             13
# 4   29  Self-emp-not-inc  189346  Some-college             10
#
#        marital-status         occupation   relationship   race     sex  \
# 0            Divorced       Adm-clerical  Not-in-family  White  Female
# 1  Married-civ-spouse    Exec-managerial           Wife  White  Female
# 2  Married-civ-spouse    Exec-managerial        Husband  Black    Male
# 3       Never-married  Machine-op-inspct  Not-in-family  White  Female
# 4            Divorced       Craft-repair  Not-in-family  White    Male
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0             0             0              38  United-States  <=50K
# 1             0             0              40  United-States  <=50K
# 2             0             0              55  United-States   >50K
# 3             0             0              40  United-States  <=50K
# 4          2202             0              50  United-States  <=50K

# %%
# Inspect Last Five Rows

df.tail()
# Out:
#       age  workclass   fnlgt     education  education-num      marital-status  \
# 6508   71    Private  269708     Bachelors             13            Divorced
# 6509   55  Local-gov  253062  Some-college             10  Married-civ-spouse
# 6510   47    Private  354148   Prof-school             15  Married-civ-spouse
# 6511   27    Private   43652     Bachelors             13       Never-married
# 6512   18    Private   25837       HS-grad              9       Never-married
#
#           occupation   relationship   race     sex  capital-gain  \
# 6508    Tech-support      Own-child  White  Female          2329
# 6509  Prof-specialty        Husband  White    Male             0
# 6510  Prof-specialty        Husband  White    Male         99999
# 6511    Adm-clerical  Not-in-family  White  Female             0
# 6512   Other-service  Not-in-family  White    Male             0
#
#       capital-loss  hours-per-week native-country salary
# 6508             0              16  United-States  <=50K
# 6509             0              40  United-States   >50K
# 6510             0              48  United-States   >50K
# 6511             0              40  United-States  <=50K
# 6512             0              25  United-States  <=50K

# %%
# Inspect Column Info Data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6513 entries, 0 to 6512
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             6513 non-null   int64
#  1   workclass       6513 non-null   object
#  2   fnlgt           6513 non-null   int64
#  3   education       6513 non-null   object
#  4   education-num   6513 non-null   int64
#  5   marital-status  6513 non-null   object
#  6   occupation      6513 non-null   object
#  7   relationship    6513 non-null   object
#  8   race            6513 non-null   object
#  9   sex             6513 non-null   object
#  10  capital-gain    6513 non-null   int64
#  11  capital-loss    6513 non-null   int64
#  12  hours-per-week  6513 non-null   int64
#  13  native-country  6513 non-null   object
#  14  salary          6513 non-null   object
# dtypes: int64(6), object(9)
# memory usage: 763.4+ KB

# %%
# Summarize Missing Data

df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlgt             0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
# Inspect Column Statistical Data

df.describe()
# Out:
#                age         fnlgt  education-num  capital-gain  capital-loss  \
# count  6513.000000  6.513000e+03    6513.000000   6513.000000   6513.000000
# mean     38.602180  1.898551e+05      10.081222   1173.759711     84.564256
# std      13.631572  1.068169e+05       2.562967   7973.158945    400.290275
# min      17.000000  1.487800e+04       1.000000      0.000000      0.000000
# 25%      28.000000  1.175070e+05       9.000000      0.000000      0.000000
# 50%      37.000000  1.790130e+05      10.000000      0.000000      0.000000
# 75%      48.000000  2.373170e+05      12.000000      0.000000      0.000000
# max      90.000000  1.268339e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count     6513.000000
# mean        40.633042
# std         12.411387
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# <H3>4. Graph the Numeric Data in the DataFrame</H3>

# %%
# Create Histogram of Numeric Column Data

# Set Veriables

Data_Columns = [
    'age',
    'fnlgt',
    'education-num',
    'capital-gain',
    'capital-loss',
    'hours-per-week'
]

Columns = 3
Rows = math.ceil(len(Data_Columns)/Columns)

# Create Figure
fig, axes = plt.subplots(Rows, Columns, figsize=(20, 12))
axes = [axes[i][j] for i in range(Rows) for j in range(Columns)]
sns.set_theme(style="dark", palette="dark", color_codes='b')

# Plot Data
for i, col in zip(range(Rows * Columns), Data_Columns):

    # Create Plot
    ax = sns.histplot(data=df, x=col, ax=axes[i])

    # Set Title
    title = col.replace('_', ' ').title()
    ax.set_title(title, fontsize=16)

# %%
# Create Kernel Density Estimate Plot of Numeric Column Data

# Set Veriables

Data_Columns = [
    'age',
    'fnlgt',
    'education-num',
    'capital-gain',
    'capital-loss',
    'hours-per-week'
]

Columns = 3
Rows = math.ceil(len(Data_Columns)/Columns)

# Create Figure
fig, axes = plt.subplots(Rows, Columns, figsize=(20, 12))
axes = [axes[i][j] for i in range(Rows) for j in range(Columns)]
sns.set_theme(style="darkgrid", palette="dark", color_codes='b')

# Plot Data
for i, col in zip(range(Rows * Columns), Data_Columns):

    # Create Plot
    ax = sns.kdeplot(data=df, x=col, ax=axes[i])

    # Set Title
    title = col.replace('_', ' ').title()
    ax.set_title(title, fontsize=16)

# %%
# Create Boxplot of Numeric Column Data

# Set Veriables

Data_Columns = [
    'age',
    'fnlgt',
    'education-num',
    'capital-gain',
    'capital-loss',
    'hours-per-week'
]

Columns = 3
Rows = math.ceil(len(Data_Columns)/Columns)

# Create Figure
fig, axes = plt.subplots(Rows, Columns, figsize=(20, 12))
axes = [axes[i][j] for i in range(Rows) for j in range(Columns)]
sns.set_theme(style="dark", palette="dark", color_codes='b')

# Plot Data
for i, col in zip(range(Rows * Columns), Data_Columns):

    # Create Plot
    ax = sns.boxplot(data=df, x=col, ax=axes[i])

    # Set Title
    title = col.replace('_', ' ').title()
    ax.set_title(title, fontsize=16)

# %% [markdown]
# <H3>4. Graph the Categorical Data in the DataFrame</H3>

# %%
# Check Workclass Values

df['workclass'].value_counts()
# Out:
# workclass
# Private             4578
# Self-emp-not-inc     498
# ?                    389
# Local-gov            387
# State-gov            254
# Self-emp-inc         212
# Federal-gov          191
# Without-pay            4
# Name: count, dtype: int64

# %%
# Plot Workclass Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'workclass', color='Blue')
plt.xticks(rotation = 60)


plt.title('Work Class Values', fontsize=14, fontweight='bold')
plt.xlabel('Work Classes', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Education Values

df['education'].value_counts()
# Out:
# education
# HS-grad         2085
# Some-college    1485
# Bachelors       1053
# Masters          369
# Assoc-voc        273
# 11th             225
# Assoc-acdm       198
# 10th             183
# 7th-8th          141
# Prof-school      116
# 9th              115
# 12th              98
# Doctorate         77
# 5th-6th           62
# 1st-4th           23
# Preschool         10
# Name: count, dtype: int64

# %%
# Plot Education Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'education', color='Blue')
plt.xticks(rotation = 60)


plt.title('Education Categorical Values', fontsize=14, fontweight='bold')
plt.xlabel('Education Category', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Marital Status Values

df['marital-status'].value_counts()
# Out:
# marital-status
# Married-civ-spouse       2950
# Never-married            2126
# Divorced                  920
# Separated                 209
# Widowed                   208
# Married-spouse-absent      96
# Married-AF-spouse           4
# Name: count, dtype: int64

# %%
# Plot Marital Status Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'marital-status', color='Blue')
plt.xticks(rotation = 60)


plt.title('Marital Status Values', fontsize=14, fontweight='bold')
plt.xlabel('Marital Status', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Occupation Values

df['occupation'].value_counts()
# Out:
# occupation
# Exec-managerial      838
# Prof-specialty       828
# Craft-repair         821
# Sales                729
# Adm-clerical         726
# Other-service        667
# ?                    389
# Machine-op-inspct    378
# Transport-moving     317
# Handlers-cleaners    273
# Farming-fishing      193
# Tech-support         189
# Protective-serv      136
# Priv-house-serv       26
# Armed-Forces           3
# Name: count, dtype: int64

# %%
# Plot Occupation Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'occupation', color='Blue')
plt.xticks(rotation = 60)


plt.title('Occupation Categorical Values', fontsize=14, fontweight='bold')
plt.xlabel('Occupation Category', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Relationship Values

df['relationship'].value_counts()
# Out:
# relationship
# Husband           2590
# Not-in-family     1702
# Own-child         1019
# Unmarried          702
# Wife               322
# Other-relative     178
# Name: count, dtype: int64

# %%
# Plot Relationship Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'relationship', color='Blue')
plt.xticks(rotation = 60)


plt.title('Relationship Categorical Values', fontsize=14, fontweight='bold')
plt.xlabel('Relationship Category', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Race Values

df['race'].value_counts()
# Out:
# race
# White                 5595
# Black                  599
# Asian-Pac-Islander     193
# Amer-Indian-Eskimo      71
# Other                   55
# Name: count, dtype: int64

# %%
# Plot Race Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'race', color='Blue')
plt.xticks(rotation = 60)


plt.title('Racial Categorical Values', fontsize=14, fontweight='bold')
plt.xlabel('Racial Category', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Sex Values

df['sex'].value_counts()
# Out:
# sex
# Male      4387
# Female    2126
# Name: count, dtype: int64

# %%
# Plot Sex Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'sex', color='Blue')
plt.xticks(rotation = 60)


plt.title('Sex Categorical Values', fontsize=14, fontweight='bold')
plt.xlabel('Sex', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Native Country Values

df['native-country'].value_counts()
# Out:
# native-country
# United-States         5870
# ?                      125
# Mexico                 114
# Philippines             35
# Germany                 32
# Puerto-Rico             22
# Canada                  22
# India                   21
# El-Salvador             20
# Cuba                    19
# China                   18
# Poland                  14
# England                 14
# Italy                   14
# South                   13
# Jamaica                 13
# Guatemala               13
# Iran                    12
# Taiwan                  11
# Japan                   11
# Dominican-Republic       8
# Hong                     8
# Nicaragua                7
# Greece                   7
# Haiti                    6
# Columbia                 6
# Portugal                 6
# Vietnam                  5
# Thailand                 5
# France                   5
# Peru                     5
# Ireland                  5
# Ecuador                  5
# Laos                     4
# Honduras                 4
# Hungary                  3
# Trinadad&Tobago          3
# Scotland                 3
# Cambodia                 3
# Yugoslavia               2
# Name: count, dtype: int64

# %%
# Plot Native Country Values

plt.figure(figsize = [24, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'native-country', color='Blue')
plt.xticks(rotation = 60)


plt.title('Native Country Values', fontsize=14, fontweight='bold')
plt.xlabel('Native Country', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Salary Values

df['salary'].value_counts()
# Out:
# salary
# <=50K    4942
# >50K     1571
# Name: count, dtype: int64

# %%
# Plot Salary Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'salary', color='Blue')
plt.xticks(rotation = 60)


plt.title('Salary Group Values', fontsize=14, fontweight='bold')
plt.xlabel('Salary Group', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');
