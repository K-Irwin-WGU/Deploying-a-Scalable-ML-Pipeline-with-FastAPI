# %% [markdown]
# <H1>Test Data Exploratory Data Analysis (EDA)</H1>

# %% [markdown]
# <H3>1. Install Packages</H3>

# %%
# Import Packages

import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <H3>2. Get Test Data and Read it with Pandas</H3>

# %%
# Load Data into DataFrame

df = pd.read_csv("../data/test_data.csv")

# %% [markdown]
# <H3>3. Explore the Data in the DataFrame</H3>

# %%
# Get Basic df Shape

df.shape
# Out:
# (6513, 15)

# %%
# Inspect First Five Rows

df.head()
# Out:
#    age     workclass   fnlgt     education  education-num      marital-status  \
# 0   27       Private  491421       5th-6th              3       Never-married
# 1   23     State-gov  136075     Bachelors             13       Never-married
# 2   56       Private  435022  Some-college             10            Divorced
# 3   22       Private  140001     Bachelors             13       Never-married
# 4   47  Self-emp-inc  483596       HS-grad              9  Married-civ-spouse
#
#         occupation   relationship   race     sex  capital-gain  capital-loss  \
# 0  Farming-fishing      Unmarried  White    Male             0             0
# 1   Prof-specialty  Not-in-family  White  Female             0             0
# 2    Other-service  Not-in-family  White  Female             0             0
# 3     Adm-clerical  Not-in-family  White    Male             0             0
# 4  Exec-managerial        Husband  White    Male          2885             0
#
#    hours-per-week native-country salary
# 0              50  United-States  <=50K
# 1              32  United-States  <=50K
# 2              50  United-States  <=50K
# 3              40  United-States  <=50K
# 4              32  United-States  <=50K

# %%
# Inspect Last Five Rows

df.tail()
# Out:
#       age         workclass   fnlgt  education  education-num  \
# 6508   64           Private  212838    HS-grad              9
# 6509   40           Private  346847  Assoc-voc             11
# 6510   18           Private  193741       11th              7
# 6511   72           Private  205343       11th              7
# 6512   38  Self-emp-not-inc  233571    HS-grad              9
#
#           marital-status      occupation    relationship   race     sex  \
# 6508  Married-civ-spouse           Sales         Husband  White    Male
# 6509           Separated  Prof-specialty  Other-relative  White  Female
# 6510       Never-married   Other-service  Other-relative  Black    Male
# 6511             Widowed    Adm-clerical       Unmarried  White  Female
# 6512           Separated   Other-service       Unmarried  White  Female
#
#       capital-gain  capital-loss  hours-per-week native-country salary
# 6508             0             0              65  United-States   >50K
# 6509             0             0              40  United-States  <=50K
# 6510             0             0              30  United-States  <=50K
# 6511             0             0              40  United-States  <=50K
# 6512             0             0              40  United-States  <=50K

# %%
# Inspect Column Info Data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6513 entries, 0 to 6512
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             6513 non-null   int64
#  1   workclass       6513 non-null   object
#  2   fnlgt           6513 non-null   int64
#  3   education       6513 non-null   object
#  4   education-num   6513 non-null   int64
#  5   marital-status  6513 non-null   object
#  6   occupation      6513 non-null   object
#  7   relationship    6513 non-null   object
#  8   race            6513 non-null   object
#  9   sex             6513 non-null   object
#  10  capital-gain    6513 non-null   int64
#  11  capital-loss    6513 non-null   int64
#  12  hours-per-week  6513 non-null   int64
#  13  native-country  6513 non-null   object
#  14  salary          6513 non-null   object
# dtypes: int64(6), object(9)
# memory usage: 763.4+ KB

# %%
# Summarize Missing Data

df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlgt             0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
# Inspect Column Statistical Data

df.describe()
# Out:
#                age          fnlgt  education-num  capital-gain  capital-loss  \
# count  6513.000000    6513.000000    6513.000000   6513.000000   6513.000000
# mean     38.586366  189845.893597      10.122831   1108.143252     86.926148
# std      13.551622  105906.866212       2.548719   7429.618687    401.833863
# min      17.000000   19302.000000       1.000000      0.000000      0.000000
# 25%      28.000000  117721.000000       9.000000      0.000000      0.000000
# 50%      37.000000  177728.000000      10.000000      0.000000      0.000000
# 75%      48.000000  236592.000000      12.000000      0.000000      0.000000
# max      90.000000  981628.000000      16.000000  99999.000000   3900.000000
#
#        hours-per-week
# count     6513.000000
# mean        40.707815
# std         12.389369
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# <H3>4. Graph the Numeric Data in the DataFrame</H3>

# %%
# Create Histogram of Numeric Column Data

# Set Veriables

Data_Columns = [
    'age',
    'fnlgt',
    'education-num',
    'capital-gain',
    'capital-loss',
    'hours-per-week'
]

Columns = 3
Rows = math.ceil(len(Data_Columns)/Columns)

# Create Figure
fig, axes = plt.subplots(Rows, Columns, figsize=(20, 12))
axes = [axes[i][j] for i in range(Rows) for j in range(Columns)]
sns.set_theme(style="dark", palette="dark", color_codes='b')

# Plot Data
for i, col in zip(range(Rows * Columns), Data_Columns):

    # Create Plot
    ax = sns.histplot(data=df, x=col, ax=axes[i])

    # Set Title
    title = col.replace('_', ' ').title()
    ax.set_title(title, fontsize=16)

# %%
# Create Kernel Density Estimate Plot of Numeric Column Data

# Set Veriables

Data_Columns = [
    'age',
    'fnlgt',
    'education-num',
    'capital-gain',
    'capital-loss',
    'hours-per-week'
]

Columns = 3
Rows = math.ceil(len(Data_Columns)/Columns)

# Create Figure
fig, axes = plt.subplots(Rows, Columns, figsize=(20, 12))
axes = [axes[i][j] for i in range(Rows) for j in range(Columns)]
sns.set_theme(style="darkgrid", palette="dark", color_codes='b')

# Plot Data
for i, col in zip(range(Rows * Columns), Data_Columns):

    # Create Plot
    ax = sns.kdeplot(data=df, x=col, ax=axes[i])

    # Set Title
    title = col.replace('_', ' ').title()
    ax.set_title(title, fontsize=16)

# %%
# Create Boxplot of Numeric Column Data

# Set Veriables

Data_Columns = [
    'age',
    'fnlgt',
    'education-num',
    'capital-gain',
    'capital-loss',
    'hours-per-week'
]

Columns = 3
Rows = math.ceil(len(Data_Columns)/Columns)

# Create Figure
fig, axes = plt.subplots(Rows, Columns, figsize=(20, 12))
axes = [axes[i][j] for i in range(Rows) for j in range(Columns)]
sns.set_theme(style="dark", palette="dark", color_codes='b')

# Plot Data
for i, col in zip(range(Rows * Columns), Data_Columns):

    # Create Plot
    ax = sns.boxplot(data=df, x=col, ax=axes[i])

    # Set Title
    title = col.replace('_', ' ').title()
    ax.set_title(title, fontsize=16)

# %% [markdown]
# <H3>4. Graph the Categorical Data in the DataFrame</H3>

# %%
# Check Workclass Values

df['workclass'].value_counts()
# Out:
# workclass
# Private             4597
# Self-emp-not-inc     498
# Local-gov            396
# ?                    359
# State-gov            258
# Federal-gov          206
# Self-emp-inc         196
# Without-pay            3
# Name: count, dtype: int64

# %%
# Plot Workclass Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'workclass', color='Blue')
plt.xticks(rotation = 60)


plt.title('Work Class Values', fontsize=14, fontweight='bold')
plt.xlabel('Work Classes', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Education Values

df['education'].value_counts()
# Out:
# education
# HS-grad         2107
# Some-college    1464
# Bachelors       1012
# Masters          374
# Assoc-voc        298
# 11th             233
# Assoc-acdm       221
# 10th             174
# Prof-school      138
# 7th-8th          117
# 9th              109
# 12th              84
# Doctorate         82
# 5th-6th           67
# 1st-4th           29
# Preschool          4
# Name: count, dtype: int64

# %%
# Plot Education Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'education', color='Blue')
plt.xticks(rotation = 60)


plt.title('Education Categorical Values', fontsize=14, fontweight='bold')
plt.xlabel('Education Category', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Marital Status Values

df['marital-status'].value_counts()
# Out:
# marital-status
# Married-civ-spouse       3060
# Never-married            2082
# Divorced                  885
# Widowed                   193
# Separated                 191
# Married-spouse-absent      97
# Married-AF-spouse           5
# Name: count, dtype: int64

# %%
# Plot Marital Status Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'marital-status', color='Blue')
plt.xticks(rotation = 60)


plt.title('Marital Status Values', fontsize=14, fontweight='bold')
plt.xlabel('Marital Status', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Occupation Values

df['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty       879
# Craft-repair         814
# Exec-managerial      805
# Adm-clerical         784
# Sales                697
# Other-service        622
# Machine-op-inspct    397
# ?                    359
# Transport-moving     327
# Handlers-cleaners    268
# Farming-fishing      217
# Tech-support         195
# Protective-serv      121
# Priv-house-serv       25
# Armed-Forces           3
# Name: count, dtype: int64

# %%
# Plot Occupation Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'occupation', color='Blue')
plt.xticks(rotation = 60)


plt.title('Occupation Categorical Values', fontsize=14, fontweight='bold')
plt.xlabel('Occupation Category', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Relationship Values

df['relationship'].value_counts()
# Out:
# relationship
# Husband           2694
# Not-in-family     1578
# Own-child         1010
# Unmarried          713
# Wife               328
# Other-relative     190
# Name: count, dtype: int64

# %%
# Plot Relationship Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'relationship', color='Blue')
plt.xticks(rotation = 60)


plt.title('Relationship Categorical Values', fontsize=14, fontweight='bold')
plt.xlabel('Relationship Category', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Race Values

df['race'].value_counts()
# Out:
# race
# White                 5563
# Black                  651
# Asian-Pac-Islander     188
# Amer-Indian-Eskimo      56
# Other                   55
# Name: count, dtype: int64

# %%
# Plot Race Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'race', color='Blue')
plt.xticks(rotation = 60)


plt.title('Racial Categorical Values', fontsize=14, fontweight='bold')
plt.xlabel('Racial Category', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Sex Values

df['sex'].value_counts()
# Out:
# sex
# Male      4387
# Female    2126
# Name: count, dtype: int64

# %%
# Plot Sex Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'sex', color='Blue')
plt.xticks(rotation = 60)


plt.title('Sex Categorical Values', fontsize=14, fontweight='bold')
plt.xlabel('Sex', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Native Country Values

df['native-country'].value_counts()
# Out:
# native-country
# United-States                 5841
# Mexico                         130
# ?                              107
# Philippines                     43
# Germany                         27
# England                         26
# Canada                          23
# Dominican-Republic              17
# China                           16
# Italy                           16
# Jamaica                         16
# Puerto-Rico                     15
# Columbia                        14
# Vietnam                         14
# Cuba                            14
# South                           14
# Guatemala                       13
# Poland                          13
# Taiwan                          13
# India                           13
# El-Salvador                     12
# Japan                           11
# Ireland                          9
# Portugal                         9
# Haiti                            9
# Peru                             8
# Nicaragua                        8
# Iran                             7
# Ecuador                          6
# Outlying-US(Guam-USVI-etc)       6
# France                           5
# Trinadad&Tobago                  5
# Thailand                         5
# Cambodia                         5
# Yugoslavia                       5
# Laos                             5
# Hong                             5
# Honduras                         3
# Greece                           2
# Scotland                         2
# Hungary                          1
# Name: count, dtype: int64

# %%
# Plot Native Country Values

plt.figure(figsize = [24, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'native-country', color='Blue')
plt.xticks(rotation = 60)


plt.title('Native Country Values', fontsize=14, fontweight='bold')
plt.xlabel('Native Country', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');

# %%
# Check Salary Values

df['salary'].value_counts()
# Out:
# salary
# <=50K    4877
# >50K     1636
# Name: count, dtype: int64

# %%
# Plot Salary Values

plt.figure(figsize = [15, 8])
plt.rcParams['axes.facecolor'] = 'Black'

data = df

# Bar Chart of Values 
sns.countplot(data = data, x = 'salary', color='Blue')
plt.xticks(rotation = 60)


plt.title('Salary Group Values', fontsize=14, fontweight='bold')
plt.xlabel('Salary Group', fontsize=12, fontweight='bold')
plt.ylabel('Number of People', fontsize=12, fontweight='bold');
